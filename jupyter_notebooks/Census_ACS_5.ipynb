# %%
import pandas as pd

# Dependencies
import requests

import time
import json

#Census api_key
from config import api_key

# %%
# df = df[1:]

# %%
api_base_route = "https://api.census.gov/data"
data_set_name_acs5 = "acs/acs5"
year_acs5 = 2021
variables_acs5 = "NAME,B19001_001E,B19001_014E,B19001_015E,B19001_016E,B19001_017E,\
B09002_001E,B09002_002E,B09002_005E,B09002_006E,B09002_007E,B09002_008E,B09002_009E,\
B09002_012E,B09002_013E,B09002_014E,B09002_015E,B09002_018E,B09002_019E,B09002_020E"
acs5_query_url = f"{api_base_route}/{year_acs5}/{data_set_name_acs5}?get={variables_acs5}&for=block%20group:*&in=state:06%20county:073&key={api_key}"
acs5_query_url
# Out:
# 'https://api.census.gov/data/2021/acs/acs5?get=NAME,B19001_001E,B19001_014E,B19001_015E,B19001_016E,B19001_017E,B09002_001E,B09002_002E,B09002_005E,B09002_006E,B09002_007E,B09002_008E,B09002_009E,B09002_012E,B09002_013E,B09002_014E,B09002_015E,B09002_018E,B09002_019E,B09002_020E,B09002_003E,B09002_004E,B09002_010E,B09002_011E,B09002_016E,B09002_017E&for=block%20group:*&in=state:06%20county:073&key=1a63c0cea26c0b7e1515f363e7d0afe0b8c67ff8'

# %%
acs5_data_df = pd.read_json(acs5_query_url)
acs5_data_df.head(10)
# Out:
#                                                   0            1   \
# 0                                               NAME  B19001_001E
# 1  Block Group 1, Census Tract 1, San Diego Count...          535
# 2  Block Group 2, Census Tract 1, San Diego Count...          615
# 3  Block Group 1, Census Tract 2.01, San Diego Co...          427
# 4  Block Group 2, Census Tract 2.01, San Diego Co...          760
# 5  Block Group 1, Census Tract 2.02, San Diego Co...          795
# 6  Block Group 2, Census Tract 2.02, San Diego Co...          441
# 7  Block Group 3, Census Tract 2.02, San Diego Co...          641
# 8  Block Group 4, Census Tract 2.02, San Diego Co...          396
# 9  Block Group 1, Census Tract 3.01, San Diego Co...          441
#
#             2            3            4            5            6   \
# 0  B19001_014E  B19001_015E  B19001_016E  B19001_017E  B09002_001E
# 1           13           51           71          256          326
# ...

# %%
acs5_data_df = acs5_data_df[1:]
acs5_data_df
# Out:
#                                                      0    1   2    3    4   \
# 1     Block Group 1, Census Tract 1, San Diego Count...  535  13   51   71
# 2     Block Group 2, Census Tract 1, San Diego Count...  615  46   46   28
# 3     Block Group 1, Census Tract 2.01, San Diego Co...  427  28   52   91
# 4     Block Group 2, Census Tract 2.01, San Diego Co...  760  20   24   97
# 5     Block Group 1, Census Tract 2.02, San Diego Co...  795  61    0   40
# ...                                                 ...  ...  ..  ...  ...
# 2054  Block Group 1, Census Tract 221.02, San Diego ...  765   0  114   63
# 2055  Block Group 2, Census Tract 221.02, San Diego ...  605  75   49  148
# 2056  Block Group 3, Census Tract 221.02, San Diego ...  656   0   27   65
# 2057  Block Group 4, Census Tract 221.02, San Diego ...  794  87    0   27
# 2058  Block Group 0, Census Tract 9901, San Diego Co...    0   0    0    0
#
# ...

# %%
acs5_data_df.set_axis(['Name',
                       'Household Income Total',
                       'Income 100000 to 124999',
                       'Income 125000 to 149999',
                       'Income 150000 to 199999',
                       'Income 200000 or more',
                       'Total Children Under 18y','Total Children Under 18 in Married',
                       'Total 5y','Total 6 to 11y','Total 12 to 17y', 
                       'Total Children in Other Families',
                       'Total Children Under 18 w/Male Housholder',
                       'Total 5y w/Male Housholder',
                       'Total 6 to 11y w/Male Housholder',
                       'Total 12 to 17y w/Male Housholder', 
                        'Total Children Under 18 w/Female Housholder',
                       'Total 5y w/Female Housholder',
                       'Total 6 to 11y w/Female Housholder',
                       'Total 12 to 17y w/Female Housholder',
                       'State','County','Tract','Block Group'],axis=1, inplace= True)

# %%
acs5_data_df.head(50)
# Out:
#                                                  Name Household Income Total  \
# 1   Block Group 1, Census Tract 1, San Diego Count...                    535
# 2   Block Group 2, Census Tract 1, San Diego Count...                    615
# 3   Block Group 1, Census Tract 2.01, San Diego Co...                    427
# 4   Block Group 2, Census Tract 2.01, San Diego Co...                    760
# 5   Block Group 1, Census Tract 2.02, San Diego Co...                    795
# 6   Block Group 2, Census Tract 2.02, San Diego Co...                    441
# 7   Block Group 3, Census Tract 2.02, San Diego Co...                    641
# 8   Block Group 4, Census Tract 2.02, San Diego Co...                    396
# 9   Block Group 1, Census Tract 3.01, San Diego Co...                    441
# 10  Block Group 2, Census Tract 3.01, San Diego Co...                    405
# 11  Block Group 3, Census Tract 3.01, San Diego Co...                    493
# ...

# %%
# acs5_data_df.to_csv('asc5_demografics_socioeconomic.csv', index = False)

# %%
acs5_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2058 entries, 1 to 2058
# Data columns (total 24 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Name                                         2058 non-null   object
#  1   Household Income Total                       2058 non-null   object
#  2   Income 100000 to 124999                      2058 non-null   object
#  3   Income 125000 to 149999                      2058 non-null   object
#  4   Income 150000 to 199999                      2058 non-null   object
#  5   Income 200000 or more                        2058 non-null   object
#  6   Total Children Under 18y                     2058 non-null   object
#  7   Total Children Under 18 in Married           2058 non-null   object
#  8   Total 5y                                     2058 non-null   object
# ...

# %%
# Get row count
len(acs5_data_df)
# Out:
# 2058

# %%
acs5_data_df.Tract.nunique()
# Out:
# 737

# %%
#stats
acs5_data_df['Total Children Under 18 in Married'].describe()
# Out:
# count     2058
# unique     594
# top          0
# freq       118
# Name: Total Children Under 18 in Married, dtype: object

# %%
acs5_data_df['Name']=acs5_data_df['Name'].str.replace(',',';')
acs5_data_df
# Out:
#                                                                   Name  \
# 1          Block Group 1; Census Tract 1; San Diego County; California
# 2          Block Group 2; Census Tract 1; San Diego County; California
# 3       Block Group 1; Census Tract 2.01; San Diego County; California
# 4       Block Group 2; Census Tract 2.01; San Diego County; California
# 5       Block Group 1; Census Tract 2.02; San Diego County; California
# ...                                                                ...
# 2054  Block Group 1; Census Tract 221.02; San Diego County; California
# 2055  Block Group 2; Census Tract 221.02; San Diego County; California
# 2056  Block Group 3; Census Tract 221.02; San Diego County; California
# 2057  Block Group 4; Census Tract 221.02; San Diego County; California
# 2058    Block Group 0; Census Tract 9901; San Diego County; California
#
#      Household Income Total Income 100000 to 124999 Income 125000 to 149999  \
# ...

# %%
acs5_data_df.to_csv('asc5_demografics_socioeconomic.csv', index = False)
